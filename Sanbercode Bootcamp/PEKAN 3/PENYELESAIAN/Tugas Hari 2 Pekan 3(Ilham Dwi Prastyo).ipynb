# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here
fig, ax = plt.subplots()
ax.set_title('Grafik Cos Sin', fontsize='medium')
ax.set_xlabel('X-Axis Label', fontsize='small')
ax.set_ylabel('Y-Axis Label', fontsize='small')
ax.plot(x,cos, color = 'r', label = 'Cosx')
ax.plot(x,cos3, linestyle = 'dashed', color = 'g', label = '3 Cosx')
ax.plot(x,sin, linestyle = 'dashdot', color = 'b', label = 'Sin(x-90)')
ax.plot(x,sin2, marker = "x", ls = 'None', color = 'y', label = '2 Sinx')
ax.legend(loc=10, framealpha = None, bbox_to_anchor=(0.48, 0.48), fontsize='small')
#atau
# ax.legend(loc=10, facecolor = 'white', edgecolor = '#eaeaea', bbox_to_anchor=(0.48, 0.48), fontsize='small')
fig.set_size_inches(9.5,6)
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
