# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=10JkPB2hhDmkVUoCGFP6gpoRL1mvx0OPf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('austin_weather.csv')
df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   object
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1312 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1312 non-null   object
#  7   HumidityHighPercent         1317 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1317 non-null   object
#  10  SeaLevelPressureHighInches  1316 non-null   object
#  11  SeaLevelPressureAvgInches   1316 non-null   object
#  12  SeaLevelPressureLowInches   1316 non-null   object
#  13  VisibilityHighMiles         1307 non-null   object
#  14  VisibilityAvgMiles          1307 non-null   object
#  15  VisibilityLowMiles          1307 non-null   object
#  16  WindHighMPH                 1317 non-null   object
#  17  WindAvgMPH                  1319 non-null   object
#  18  WindGustMPH                 1315 non-null   object
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: int64(2), object(19)
# memory usage: 118.6+ KB

# %% [markdown]
# <h2>Soal 1: Visualisasi Scatter Plot Perbandingan Kuantitatif</h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' yang dimana tidak bisa di ubah ke bentuk float, maka replace lah terlebih dahulu data yang bernilai '-' dengan nilai NaN, gunakan method .replace(). baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# Buahlah visualisasi perbandingan kuantitatif scatter plot, sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# Berikan pendapat dari insight yang bisa di dapat dari visualisasi perbandingan kuantitatif ini!!!

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Pp5oIc-39mcw2vrw6xgCRM9GsvyRtPI5)

# %%
# code here
df=df.replace('-',np.nan)
df.fillna(method='ffill')
df[['TempAvgF','DewPointAvgF','HumidityAvgPercent','WindAvgMPH']]=df[['TempAvgF','DewPointAvgF','HumidityAvgPercent','WindAvgMPH']].astype(float)
# df.astype({'TempAvgF':'float','DewPointAvgF':'float','HumidityAvgPercent':'float','WindAvgMPH':'float'}).dtypes

fig, ax = plt.subplots(figsize=(16,8))

colorbar=ax.scatter(df['HumidityAvgPercent'],df['DewPointAvgF'], c=df['TempAvgF'], s=20*df['WindAvgMPH'], cmap='coolwarm', alpha=0.5)
fig.colorbar(colorbar)
ax.set_xlabel('Humidity Avg %')
ax.set_ylabel('Dew Point Avg (F)')
ax.set_title('Austin Weather')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# Downoad  <a href="https://blog.sanbercode.com/wp-content/uploads/2020/05/vgsales.csv">vgsales.csv</a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
# df.head()
# df[['NA_Sales']]=df[['NA_Sales']].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# <h2>Soal 2: Preparing Data</h2>
#
# Manipulasi data tersebut dengan menggroupkan berdasarkan Genre, kemudian ambil rata2 penjualan untuk setiap Region Kecuali Global_Sales berdasarkan kategori Genre.

# %%
#code here
data_genre =df.groupby('Genre')[['NA_Sales', 'EU_Sales','JP_Sales','Other_Sales']].mean()
# data_genre
data_bar=data_genre.T
data_bar.index.array.to_numpy
# np.arange(4)
# Out:
# <bound method PandasArray.to_numpy of <PandasArray>
# ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
# Length: 4, dtype: object>

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1dR4vthSt22gM_LdfSBZCMIKPL6xd7nVl)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3: Perbandingan Kuantitatif Barplot - Grouping Visualisasi Dengan Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menghasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here
# data = df['Genre'].value_counts()
# x=data.index
# x=data_bar.index.array.to_numpy
# x=data_bar.index
# x= np.arange(4)
x = np.arange(0,20,5)
# display(x)
# y1 = data_genre['NA_Sales']
# y2 = data_genre['EU_Sales']
# y3 = data_genre['JP_Sales']
# y4 = data_genre['Other_Sales']
y1 = data_bar['Action']
y2 = data_bar['Adventure']
y3 = data_bar['Fighting']
y4 = data_bar['Misc']
y5 = data_bar['Platform']
y6 = data_bar['Puzzle']
y7 = data_bar['Racing']
y8 = data_bar['Role-Playing']
y9 = data_bar['Shooter']
y10 = data_bar['Simulation']
y11 = data_bar['Sports']
y12 = data_bar['Strategy']

# plot data
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(16,8))

ax.bar(x, y1, width=0.3, label='Action',color='#e14932')
ax.bar(x+0.3, y2, width=0.3, label='Adventure',color='#348abd')
ax.bar(x+0.6, y3, width=0.3, label='Fighting',color='#988dd5')
ax.bar(x+0.9, y4, width=0.3, label='Misc',color='#777777')
ax.bar(x+1.2, y5, width=0.3, label='Platform', color='#fbc15e')
ax.bar(x+1.5, y6, width=0.3, label='Puzzle', color='#8db941')
ax.bar(x+1.8, y7, width=0.3, label='Racing', color='#ffb5b8')
ax.bar(x+2.1, y8, width=0.3, label='Role-Playing', color='#e14932')
ax.bar(x+2.4, y9, width=0.3, label='Shooter', color='#348abd')
ax.bar(x+2.7, y10, width=0.3, label='Simulation', color='#978dd5')
ax.bar(x+3, y11, width=0.3, label='Sports', color='#777777')
ax.bar(x+3.3, y12, width=0.3, label='Strategy', color='#fbc05e')
# plt.xticks(x, list(data_bar.index))
# ax.set_xticklabels(['']+list(data_bar.index))
# ax.set_xticklabels(['',data_bar.index.array[0],'',data_bar.index.array[1],'',data_bar.index.array[2],'',data_bar.index.array[3]])
# ax.set_xtickslabels(list(data_bar.index))
ax.set_xlabel('Region Sales')
ax.set_ylabel('Mean Sales')
ax.set_title('Mean Sales Video Games By Genre')
plt.legend()
plt.show()

# %%
np.arange(4)
# data = df['Genre'].value_counts()
# data
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# Jawab:

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1A2s9Uy2i471VEYIZqMoVUIlZnVOUc8ha)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 4: Perbandingan Kuantitatif Barplot - Stack Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menhasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here
x = np.arange(4)
# y1 = data_genre['NA_Sales']
# y2 = data_genre['EU_Sales']
# y3 = data_genre['JP_Sales']
# y4 = data_genre['Other_Sales']
y1 = data_genre.loc['Action']
y2 = data_genre.loc['Adventure']
y3 = data_genre.loc['Fighting']
y4 = data_genre.loc['Misc']
y5 = data_genre.loc['Platform']
y6 = data_genre.loc['Puzzle']
y7 = data_genre.loc['Racing']
y8 = data_genre.loc['Role-Playing']
y9 = data_genre.loc['Shooter']
y10 = data_genre.loc['Simulation']
y11 = data_genre.loc['Sports']
y12 = data_genre.loc['Strategy']

# plot data
fig, ax = plt.subplots(figsize=(16,8))

ax.bar(x, y1,label='Action')
ax.bar(x, y2, bottom=y1,label='Adventure')
ax.bar(x, y3, bottom=y1+y2,label='Fighting')
ax.bar(x, y4, bottom=y1+y2+y3,label='Misc')
ax.bar(x, y5, bottom=y1+y2+y3+y4,label='Platform')
ax.bar(x, y6, bottom=y1+y2+y3+y4+y5,label='Puzzle')
ax.bar(x, y7, bottom=y1+y2+y3+y4+y5+y6,label='Racing')
ax.bar(x, y8, bottom=y1+y2+y3+y4+y5+y6+y7,label='Role-Playing')
ax.bar(x, y9, bottom=y1+y2+y3+y4+y5+y6+y7+y8,label='Shooter')
ax.bar(x, y10, bottom=y1+y2+y3+y4+y5+y6+y7+y8+y9,label='Simulation')
ax.bar(x, y11, bottom=y1+y2+y3+y4+y5+y6+y7+y8+y9+y10,label='Sports')
ax.bar(x, y12, bottom=y1+y2+y3+y4+y5+y6+y7+y8+y9+y1-+y11,label='Strategy')
ax.set_xticklabels([0]+list(data_genre.columns))
ax.set_xlabel('Region Sales')
ax.set_ylabel('Mean Sales')
ax.set_title('Mean Sales Video Games By Genre')
plt.legend(bbox_to_anchor=(0.5,0.5))
plt.style.context('ggplot')
plt.show()
# Out:
# <ipython-input-281-191efe32c47e>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([0]+list(data_genre.columns))

# %% [markdown]
# Jawab:

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1_yis-3aZsEbsk68tpoPHoNlFftaz2GrO)
