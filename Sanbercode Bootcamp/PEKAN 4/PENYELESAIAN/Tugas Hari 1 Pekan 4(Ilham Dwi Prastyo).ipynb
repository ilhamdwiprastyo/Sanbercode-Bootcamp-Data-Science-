# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# - machine learning adalah bidang yang merupakan bagian dari Artificial Intelligence (AI) yang digunakan agar sistem komputer secara otomatis dapat belajar dengan sendirinya tanpa diberi instruksi pemrograman dan dapat meningkatkan prediksi yang akurat dan pengunaannya biasanya sifatnya realtime. machine learning menghasilkan model matematika yang didasari dari data sampel yang sering disebut dengan ‘training data'.
# - data future adalah variabel yg bertujuan sebagai predictor dan variabel yang bisa mempengaruhi variabel lainnya. sedangkan data target adalah variabel hasil dari predictor, dengan kata lain variabel yg dipengaruhi oleh variabel lainnya.
# - Supervised Learning adalah teknik yang digunakan untuk memprediksi hasil masa depan berdasarkan data historis. Model prediktif biasanya diberi instruktsi yang jelas sejak awal seperti apa yang perlu dipelajari dan bagaimana itu perlu dipelajari. Algoritma pembelajaran ini disebut Supervised Learning.<br>Unsupervised Learning adalah teknik yang digunakan untuk melatih dimana tidak ada target yang ditetapkan dan tidak ada faktor yang penting dari yang lainnya. dengan kata lain tidak ada pengelompokan yang diinginkan.
# - Klasifikasi dan Regresi. Klasifikasi memiliki output berupa class label, sedangkan regresi memiliki output berupa kuantitas yang kontinu. klasifikasi outputnya berupa pengelompokan pada class tertentu, regresi outputnya bisa berupa value dengan rentang tertentu yang kontinu.
# - hyperparameter merupakan bagian dari parameter. hyperparameter didefinisikan diawal pembuatan model dan tidak terikat dengan model namun berguna untuk mencapai suatu model yang optimal. sedangkan parameter dihasilkan diakhir saat model terbentuk, sehingga parameter dengan model bersifat terikat.
# - 1. Pilih model atau algoritma yang akan digunakan<br>2. Pilih Hyperparameter ketika membuat objek model<br>3. Pisahkan antara data feature dan data target(sklearn menerima data berupa matriks bukan vektor)<br>4. Perintahkan model untuk mempelajari data dengan menggunakan method .fit()<br>5. Aplikasikan model kedalam test data dengan menggunakan method .predict() untuk supervised learning atau .transform() dan predict() untuk unsupervised learning

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

regr_1 = DecisionTreeRegressor(max_depth=2)
x_matriks=x[:,np.newaxis]
x_new=x_new[:,np.newaxis]
regr_1.fit(x_matriks,y)
y_train=regr_1.predict(x_matriks)
y_new=regr_1.predict(x_new)
fig, ax = plt.subplots(figsize=(12, 8))

ax.scatter(x,y, label='Data Asli', color='b')
ax.scatter(x,y_train, label = 'Prediksi terhadap data training', color='y')
ax.plot(x_new,y_new, label = 'Prediksi Terhadap Data Baru', color= 'g')
plt.legend(loc=1, bbox_to_anchor=(1.13, 1.16))
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# Code here
display(regr_1.feature_importances_)
display(regr_1.n_features_)
# Out:
# array([1.])
# 1
