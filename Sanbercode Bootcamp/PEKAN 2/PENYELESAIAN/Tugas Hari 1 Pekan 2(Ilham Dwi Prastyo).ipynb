# %% [markdown]
# <h2>Soal 1: Membuat Objek DataFrames</h2>
#
# - Buatlah objek dataframes dari objek dictionary, Bebas!

# %%
# Membuat dataframes dari dictionary
import pandas as pd
obj_dict = {"Nama Mahasiswa":['Aldi', 'Julinar', 'Syahrul', 'Zamal'],"Nilai Quiz PBO":[80,90,85,95]}
df = pd.DataFrame(obj_dict)
df
# Out:
#   Nama Mahasiswa  Nilai Quiz PBO
# 0           Aldi              80
# 1        Julinar              90
# 2        Syahrul              85
# 3          Zamal              95

# %% [markdown]
# <h2>Soal 2: Membaca data dari file</h2>
#
# Download file bernama [diamonds.csv](https://drive.google.com/uc?export=download&id=1qQiM9utQUThTPq8jk8stPMh_y2zfqYOd), kemudian baca data tersebut dan assign ke dalam suatu variabel kemudian print.

# %%
# Membaca data dan memasukannya kedalam suatu variabel
data_diamond = pd.read_csv('diamonds-1.csv')
data_diamond
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1BvgM5mJEVfj0fllrjkBfQwn0QIFkry_t)

# %% [markdown]
# <h2>Soal 3: DataFrame vs Series</h2>
#
# - Apa perbedaan Series dengan list dan dictionary
# - Apa perbedaan dataframe dan series
# - Buatlah suatu data series

# %% [markdown]
# Jawab: 1) Perbedaan Series dengan list dan dictionary adalah Secara garis besar Series merupakan kombinasi dari list dan dictionary, dimana Series indexingnya bisa menggunakan slicing seperti list sedangkan dictionary tidak bisa slicing, serta Series indexingnya bisa menggunakan labeling sedangkan list tidak bisa, key dictionary tidak bisa di duplicate sedangkan di Series bisa
#
# 2) Perbedaan dataframe dan series adalah terletak pada besar dimensi , pada series memiliki 1 dimensi sedangkan dataframe memiliki dimensi, pada series terdiri dari index saja, dan isi datanya bernama values, sedangkan pada dataframe terdiri dari index dan collumns karena 2 dimensi. Dataframe juga bisa berupa gabungan dari Series, dapat dikatakan Series merupakan himpunan bagian dari Dataframe

# %%
# code here
obj_series = pd.Series([80,70,75])
print(obj_series,'\n')
obj_series.index=['Matematika','Fisika','Kimia']
print(obj_series)
# Out:
# 0    80
# 1    70
# 2    75
# dtype: int64
#
# Matematika    80
# Fisika        70
# Kimia         75
# dtype: int64

# %% [markdown]
# <h2>Soal 4: Pemeriksaan Data Sederhana</h2>
#
# Di soal no 2 kamu telah membaca data tentang diamonds. pada soal ini cobalah suatu metode dari pandas untuk mengetahui beberapa data pertama dan beberapa data terakhir. kemudian sebutkan nilai dari:
# - baris pertama dari column price
# - baris terakhir dari column color
#
# tunjukan cara kalian menemukan nilai tersebut di block di bawah ini.

# %%
# head
data_diamond.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# tail
data_diamond.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
# baris pertama dari column price
print("baris pertama dari column price\n")
print(data_diamond.get('price').head(1),"\n")

# baris terakhir dari column color
print("baris terakhir dari column color\n")
print(data_diamond.get('color').tail(1))
# Out:
# baris pertama dari column price
#
# 0    326
# Name: price, dtype: int64
#
# baris terakhir dari column color
#
# 53939    D
# Name: color, dtype: object

# %% [markdown]
# <h2>Soal 5: Deskriptif Statistik</h2>
#
# Jelaskan apa itu deskriptis statistik!

# %% [markdown]
# Jawab: Statistik deskriptif merupakan proses analisis statistik yang fokus kepada manejemen, penyajian, dan klasifikasi data. Dengan proses ini, data yang disajikan akan menjadi lebih menarik lebih mudah dipahami, dan mampu memberikan makna lebih bagi pengguna data, data yang disajikan bisa berupa raw data, numerik, maupun grafik.

# %% [markdown]
# <h2>Soal 6: Practice Deskriptif Statistik</h2>
#
# - Gunakan suatu metode dari pandas untuk mengetahui deskriptif statistik dari suatu data
# - Berapa nilai rata-rata dari column price
# - Berapa nilai standar deviasi dari column depth
# - Berapa nilai maximum dari column carat

# %%
data_diamond.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
# code here

import matplotlib.pyplot as plt

grafik_pemusatan_data_price = data_diamond.get('price')
mean= grafik_pemusatan_data_price.mean()
median = grafik_pemusatan_data_price.median()
modus = grafik_pemusatan_data_price.mode()

plt.figure(figsize=(15,5))
plt.title('Diagaram Pemusatan Data pada Columns Price')
plt.hist(grafik_pemusatan_data_price,bins=35,color='grey')
plt.axvline(mean,color='red',label='Mean')
plt.axvline(median,color='yellow',label='Median')
plt.axvline(modus[0],color='green',label='Modus')
plt.xlabel('price')
plt.ylabel('frekuensi')
plt.legend()
plt.show()


#nilai rata-rata dari column price
print("\nnilai rata-rata dari column price adalah",data_diamond.get('price').mean())

#nilai standar deviasi dari column depth
print("nilai standar deviasi dari column depth adalah",data_diamond.get('depth').std())

#nilai maximum dari column carat
print("nilai maximum dari column carat adalah", data_diamond.get('carat').max())
# Out:
# nilai rata-rata dari column price adalah 3932.799721913237
# nilai standar deviasi dari column depth adalah 1.432621318833661
# nilai maximum dari column carat adalah 5.01

# %% [markdown]
# Jawab:
